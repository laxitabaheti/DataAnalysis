# %% [markdown]
# <a href="https://colab.research.google.com/github/laxitabaheti/DataAnalysis/blob/main/DataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/drive/MyDrive/winequality-red.csv", sep=";")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 1               7.8             0.880         0.00  ...       0.68      9.8        5
# 2               7.8             0.760         0.04  ...       0.65      9.8        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# 1598            6.0             0.310         0.47  ...       0.66     11.0        6
#
# [1599 rows x 12 columns]

# %%
x1=df["fixed acidity"]
y1=df["volatile acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("volatile acidity")

x1=df["fixed acidity"]
y1=df["residual sugar"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("residual sugar")

x1=df["fixed acidity"]
y1=df["citric acid"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("citric acid")

x1=df["fixed acidity"]
y1=df["chlorides"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("chlorides")

x1=df["fixed acidity"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("free sulfur dioxide")

x1=df["fixed acidity"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("total sulfur dioxide")

x1=df["fixed acidity"]
y1=df["density"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("residual sugar")

x1=df["fixed acidity"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("pH")

x1=df["fixed acidity"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("sulphates")

x1=df["fixed acidity"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("alcohol")

x1=df["fixed acidity"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)
plt.xlabel("fixed acidity")
plt.ylabel("quality")

plt.show()

# %% [markdown]
# Graph-7 : with increase in fixed acidity residual sugar increases
#
# Graph 8 : with increase in fixed acidity pH decreases

# %%
x1=df["volatile acidity"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("fixed acidity")

x1=df["volatile acidity"]
y1=df["residual sugar"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("residual sugar")

x1=df["volatile acidity"]
y1=df["citric acid"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("citric acid")

x1=df["volatile acidity"]
y1=df["chlorides"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("chlorides")

x1=df["volatile acidity"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("free sulfur dioxide")

x1=df["volatile acidity"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("total sulfur dioxide")

x1=df["volatile acidity"]
y1=df["density"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("density")

x1=df["volatile acidity"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("pH")

x1=df["volatile acidity"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("sulphates")

x1=df["volatile acidity"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("alcohol")

x1=df["volatile acidity"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)
plt.xlabel("volatile acidity")
plt.ylabel("quality")

plt.show()

# %% [markdown]
# Graph

# %%
x1=df["citric acid"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["residual sugar"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["chlorides"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["density"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["citric acid"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)


plt.tight_layout()
plt.show()

# %%
x1=df["residual sugar"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["chlorides"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["density"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["residual sugar"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["chlorides"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["density"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["chlorides"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["free sulfur dioxide"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["chlorides"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["density"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["free sulfur dioxide"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["total sulfur dioxide"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["chlorides"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["density"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["total sulfur dioxide"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["density"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["chlorides"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["pH"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["density"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["pH"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["chlorides"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["density"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["sulphates"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["pH"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["sulphates"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["chlorides"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["density"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["pH"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["alcohol"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["sulphates"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["alcohol"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["chlorides"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["density"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["pH"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["sulphates"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["alcohol"]
y1=df["quality"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
x1=df["quality"]
y1=df["fixed acidity"]
plt.subplot(4,3,1)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["citric acid"]
plt.subplot(4,3,2)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["volatile acidity"]
plt.subplot(4,3,3)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["residual sugar"]
plt.subplot(4,3,4)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["chlorides"]
plt.subplot(4,3,5)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["free sulfur dioxide"]
plt.subplot(4,3,6)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["total sulfur dioxide"]
plt.subplot(4,3,7)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["density"]
plt.subplot(4,3,8)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["pH"]
plt.subplot(4,3,9)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["sulphates"]
plt.subplot(4,3,10)
plt.scatter(x1, y1)

x1=df["quality"]
y1=df["alcohol"]
plt.subplot(4,3,11)
plt.scatter(x1, y1)

plt.tight_layout()
plt.show()

# %%
df.keys()
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
k=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']

def function(x,y):
  z=pearsonr(x,y)
  return z
for i in k:
  for j in k:
    if i==j:
      print(" ")
    else:
      x=df[i]
      y=df[j]
      M=function(x,y)
      print(i,j)
      print(function(x,y))
# Out:
#
# fixed acidity volatile acidity
# (-0.2561308947703821, 2.2767204431779706e-25)
# fixed acidity citric acid
# (0.671703434764106, 2.5353210618214457e-210)
# fixed acidity residual sugar
# (0.11477672449492143, 4.199464867686219e-06)
# fixed acidity chlorides
# (0.09370518632130542, 0.00017517459785438793)
# fixed acidity free sulfur dioxide
# (-0.15379419286482512, 6.335579450533808e-10)
# fixed acidity total sulfur dioxide
# (-0.11318144304548113, 5.709032856583959e-06)
# fixed acidity density
# (0.6680472921189743, 3.0747470608589978e-207)
# fixed acidity pH
# (-0.6829781945685314, 4.063034039847446e-220)
# fixed acidity sulphates
# (0.18300566393215348, 1.6486524776131155e-13)
# fixed acidity alcohol
# (-0.061668270628151084, 0.013648681625104516)
# fixed acidity quality
# (0.12405164911322429, 6.495635009282964e-07)
# volatile acidity fixed acidity
# (-0.2561308947703821, 2.2767204431779706e-25)
#
# volatile acidity citric acid
# (-0.55249568455958, 1.8056634143422275e-128)
# volatile acidity residual sugar
# (0.0019178819627907306, 0.9389167807222325)
# volatile acidity chlorides
# (0.061297772476461544, 0.014224905521195211)
# volatile acidity free sulfur dioxide
# (-0.010503827006591825, 0.6747010640337184)
# volatile acidity total sulfur dioxide
# (0.07647000482092817, 0.002213856792193685)
# volatile acidity density
# (0.02202623219521651, 0.3787553541321885)
# volatile acidity pH
# (0.2349372944073932, 1.7189939570072257e-21)
# volatile acidity sulphates
# (-0.26098668528328955, 2.6069256588975935e-26)
# volatile acidity alcohol
# (-0.20228802715325606, 3.1551902158325624e-16)
# volatile acidity quality
# (-0.3905577802640073, 2.0517148070151443e-59)
# citric acid fixed acidity
# (0.671703434764106, 2.5353210618214457e-210)
# citric acid volatile acidity
# (-0.55249568455958, 1.8056634143422275e-128)
#
# citric acid residual sugar
# (0.14357716157031417, 8.083723190069185e-09)
# citric acid chlorides
# (0.20382291382904166, 1.8637050331359642e-16)
# citric acid free sulfur dioxide
# (-0.06097812919230491, 0.014739157341032214)
# citric acid total sulfur dioxide
# (0.035533023931161464, 0.15554537485346961)
# citric acid density
# (0.36494717521125175, 1.4787950814489143e-51)
# citric acid pH
# (-0.5419041447395095, 1.0072013259121818e-122)
# citric acid sulphates
# (0.3127700438544169, 1.2652623915699414e-37)
# citric acid alcohol
# (0.10990324664156681, 1.0594619210193064e-05)
# citric acid quality
# (0.22637251431804137, 4.9912952505121016e-20)
# residual sugar fixed acidity
# (0.11477672449492143, 4.199464867686219e-06)
# residual sugar volatile acidity
# (0.0019178819627907306, 0.9389167807222325)
# residual sugar citric acid
# (0.14357716157031417, 8.083723190069185e-09)
#
# residual sugar chlorides
# (0.05560953520353217, 0.026170790715020646)
# residual sugar free sulfur dioxide
# (0.1870489951042869, 4.6847352594896096e-14)
# residual sugar total sulfur dioxide
# (0.20302788169710123, 2.449285445133578e-16)
# residual sugar density
# (0.35528337098337653, 9.013041728300921e-49)
# residual sugar pH
# (-0.08565242221887162, 0.0006065914586969014)
# residual sugar sulphates
# (0.005527121339138299, 0.8252134336677415)
# residual sugar alcohol
# (0.04207543720973106, 0.09258424937202335)
# residual sugar quality
# (0.01373163734006628, 0.5832180131585295)
# chlorides fixed acidity
# (0.09370518632130542, 0.00017517459785438793)
# chlorides volatile acidity
# (0.061297772476461544, 0.014224905521195211)
# chlorides citric acid
# (0.20382291382904166, 1.8637050331359642e-16)
# chlorides residual sugar
# (0.05560953520353217, 0.026170790715020646)
#
# chlorides free sulfur dioxide
# (0.005562147004781115, 0.8241238441628107)
# chlorides total sulfur dioxide
# (0.0474004682590752, 0.05809120223360299)
# chlorides density
# (0.20063232664151334, 5.541457564531321e-16)
# chlorides pH
# (-0.26502613117322743, 4.149216937884377e-27)
# chlorides sulphates
# (0.3712604812854257, 1.986309610891376e-53)
# chlorides alcohol
# (-0.22114054478828266, 3.654950031876242e-19)
# chlorides quality
# (-0.1289065599300527, 2.3133826540602144e-07)
# free sulfur dioxide fixed acidity
# (-0.15379419286482512, 6.335579450533808e-10)
# free sulfur dioxide volatile acidity
# (-0.010503827006591825, 0.6747010640337184)
# free sulfur dioxide citric acid
# (-0.06097812919230491, 0.014739157341032214)
# free sulfur dioxide residual sugar
# (0.1870489951042869, 4.6847352594896096e-14)
# free sulfur dioxide chlorides
# (0.005562147004781115, 0.8241238441628107)
#
# free sulfur dioxide total sulfur dioxide
# (0.6676664504810215, 6.404722954687316e-207)
# free sulfur dioxide density
# (-0.02194583116349004, 0.38049846539572213)
# free sulfur dioxide pH
# (0.07037749850494185, 0.004869975386135814)
# free sulfur dioxide sulphates
# (0.05165757184282854, 0.038883210655314054)
# free sulfur dioxide alcohol
# (-0.06940835356499987, 0.005492313852321059)
# free sulfur dioxide quality
# (-0.05065605724427638, 0.042833979508175565)
# total sulfur dioxide fixed acidity
# (-0.11318144304548113, 5.709032856583959e-06)
# total sulfur dioxide volatile acidity
# (0.07647000482092817, 0.002213856792193685)
# total sulfur dioxide citric acid
# (0.035533023931161464, 0.15554537485346961)
# total sulfur dioxide residual sugar
# (0.20302788169710123, 2.449285445133578e-16)
# total sulfur dioxide chlorides
# (0.0474004682590752, 0.05809120223360299)
# total sulfur dioxide free sulfur dioxide
# (0.6676664504810215, 6.404722954687316e-207)
#
# total sulfur dioxide density
# (0.07126947620310296, 0.004354283989415269)
# total sulfur dioxide pH
# (-0.06649455901285588, 0.007818340576409224)
# total sulfur dioxide sulphates
# (0.04294683623953828, 0.08601834757029696)
# total sulfur dioxide alcohol
# (-0.20565394374367094, 9.890520390087737e-17)
# total sulfur dioxide quality
# (-0.18510028892653785, 8.62170342366267e-14)
# density fixed acidity
# (0.6680472921189743, 3.0747470608589978e-207)
# density volatile acidity
# (0.02202623219521651, 0.3787553541321885)
# density citric acid
# (0.36494717521125175, 1.4787950814489143e-51)
# density residual sugar
# (0.35528337098337653, 9.013041728300921e-49)
# density chlorides
# (0.20063232664151334, 5.541457564531321e-16)
# density free sulfur dioxide
# (-0.02194583116349004, 0.38049846539572213)
# density total sulfur dioxide
# (0.07126947620310296, 0.004354283989415269)
#
# density pH
# (-0.34169933478503145, 5.117102011974621e-45)
# density sulphates
# (0.14850641172078502, 2.4184741727651457e-09)
# density alcohol
# (-0.4961797702417011, 3.938835339993499e-100)
# density quality
# (-0.1749192277833501, 1.8749566520107985e-12)
# pH fixed acidity
# (-0.6829781945685314, 4.063034039847446e-220)
# pH volatile acidity
# (0.2349372944073932, 1.7189939570072257e-21)
# pH citric acid
# (-0.5419041447395095, 1.0072013259121818e-122)
# pH residual sugar
# (-0.08565242221887162, 0.0006065914586969014)
# pH chlorides
# (-0.26502613117322743, 4.149216937884377e-27)
# pH free sulfur dioxide
# (0.07037749850494185, 0.004869975386135814)
# pH total sulfur dioxide
# (-0.06649455901285588, 0.007818340576409224)
# pH density
# (-0.34169933478503145, 5.117102011974621e-45)
#
# pH sulphates
# (-0.1966476023043702, 2.106734103689356e-15)
# pH alcohol
# (0.20563250850549822, 9.96449774146556e-17)
# pH quality
# (-0.05773139120538214, 0.020962778651490887)
# sulphates fixed acidity
# (0.18300566393215348, 1.6486524776131155e-13)
# sulphates volatile acidity
# (-0.26098668528328955, 2.6069256588975935e-26)
# sulphates citric acid
# (0.3127700438544169, 1.2652623915699414e-37)
# sulphates residual sugar
# (0.005527121339138299, 0.8252134336677415)
# sulphates chlorides
# (0.3712604812854257, 1.986309610891376e-53)
# sulphates free sulfur dioxide
# (0.05165757184282854, 0.038883210655314054)
# sulphates total sulfur dioxide
# (0.04294683623953828, 0.08601834757029696)
# sulphates density
# (0.14850641172078502, 2.4184741727651457e-09)
# sulphates pH
# (-0.1966476023043702, 2.106734103689356e-15)
#
# sulphates alcohol
# (0.09359475041046736, 0.00017830530851016817)
# sulphates quality
# (0.25139707906926123, 1.8020884534539657e-24)
# alcohol fixed acidity
# (-0.061668270628151084, 0.013648681625104516)
# alcohol volatile acidity
# (-0.20228802715325606, 3.1551902158325624e-16)
# alcohol citric acid
# (0.10990324664156681, 1.0594619210193064e-05)
# alcohol residual sugar
# (0.04207543720973106, 0.09258424937202335)
# alcohol chlorides
# (-0.22114054478828266, 3.654950031876242e-19)
# alcohol free sulfur dioxide
# (-0.06940835356499987, 0.005492313852321059)
# alcohol total sulfur dioxide
# (-0.20565394374367094, 9.890520390087737e-17)
# alcohol density
# (-0.4961797702417011, 3.938835339993499e-100)
# alcohol pH
# (0.20563250850549822, 9.96449774146556e-17)
# alcohol sulphates
# (0.09359475041046736, 0.00017830530851016817)
#
# alcohol quality
# (0.4761663240011362, 2.831476974777616e-91)
# quality fixed acidity
# (0.12405164911322429, 6.495635009282964e-07)
# quality volatile acidity
# (-0.3905577802640073, 2.0517148070151443e-59)
# quality citric acid
# (0.22637251431804137, 4.9912952505121016e-20)
# quality residual sugar
# (0.01373163734006628, 0.5832180131585295)
# quality chlorides
# (-0.1289065599300527, 2.3133826540602144e-07)
# quality free sulfur dioxide
# (-0.05065605724427638, 0.042833979508175565)
# quality total sulfur dioxide
# (-0.18510028892653785, 8.62170342366267e-14)
# quality density
# (-0.1749192277833501, 1.8749566520107985e-12)
# quality pH
# (-0.05773139120538214, 0.020962778651490887)
# quality sulphates
# (0.25139707906926123, 1.8020884534539657e-24)
# quality alcohol
# (0.4761663240011362, 2.831476974777616e-91)

# %%
k=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']
from scipy.stats import pearsonr


def function(x,y):
  z = pearsonr(x,y)
  return z


L=[]

for i in k:
  for j in k:
    if i==j:
      print(" ")
    else:
      x=df[i] 
      y=df[j]
      M=function(x,y)
      L.append(M)
      print(i,j)
      print(function(x,y))
# Out:
#
# fixed acidity volatile acidity
# (-0.2561308947703821, 2.2767204431779706e-25)
# fixed acidity citric acid
# (0.671703434764106, 2.5353210618214457e-210)
# fixed acidity residual sugar
# (0.11477672449492143, 4.199464867686219e-06)
# fixed acidity chlorides
# (0.09370518632130542, 0.00017517459785438793)
# fixed acidity free sulfur dioxide
# (-0.15379419286482512, 6.335579450533808e-10)
# fixed acidity total sulfur dioxide
# (-0.11318144304548113, 5.709032856583959e-06)
# fixed acidity density
# (0.6680472921189743, 3.0747470608589978e-207)
# fixed acidity pH
# (-0.6829781945685314, 4.063034039847446e-220)
# fixed acidity sulphates
# (0.18300566393215348, 1.6486524776131155e-13)
# fixed acidity alcohol
# (-0.061668270628151084, 0.013648681625104516)
# fixed acidity quality
# (0.12405164911322429, 6.495635009282964e-07)
# volatile acidity fixed acidity
# (-0.2561308947703821, 2.2767204431779706e-25)
#
# volatile acidity citric acid
# (-0.55249568455958, 1.8056634143422275e-128)
# volatile acidity residual sugar
# (0.0019178819627907306, 0.9389167807222325)
# volatile acidity chlorides
# (0.061297772476461544, 0.014224905521195211)
# volatile acidity free sulfur dioxide
# (-0.010503827006591825, 0.6747010640337184)
# volatile acidity total sulfur dioxide
# (0.07647000482092817, 0.002213856792193685)
# volatile acidity density
# (0.02202623219521651, 0.3787553541321885)
# volatile acidity pH
# (0.2349372944073932, 1.7189939570072257e-21)
# volatile acidity sulphates
# (-0.26098668528328955, 2.6069256588975935e-26)
# volatile acidity alcohol
# (-0.20228802715325606, 3.1551902158325624e-16)
# volatile acidity quality
# (-0.3905577802640073, 2.0517148070151443e-59)
# citric acid fixed acidity
# (0.671703434764106, 2.5353210618214457e-210)
# citric acid volatile acidity
# (-0.55249568455958, 1.8056634143422275e-128)
#
# citric acid residual sugar
# (0.14357716157031417, 8.083723190069185e-09)
# citric acid chlorides
# (0.20382291382904166, 1.8637050331359642e-16)
# citric acid free sulfur dioxide
# (-0.06097812919230491, 0.014739157341032214)
# citric acid total sulfur dioxide
# (0.035533023931161464, 0.15554537485346961)
# citric acid density
# (0.36494717521125175, 1.4787950814489143e-51)
# citric acid pH
# (-0.5419041447395095, 1.0072013259121818e-122)
# citric acid sulphates
# (0.3127700438544169, 1.2652623915699414e-37)
# citric acid alcohol
# (0.10990324664156681, 1.0594619210193064e-05)
# citric acid quality
# (0.22637251431804137, 4.9912952505121016e-20)
# residual sugar fixed acidity
# (0.11477672449492143, 4.199464867686219e-06)
# residual sugar volatile acidity
# (0.0019178819627907306, 0.9389167807222325)
# residual sugar citric acid
# (0.14357716157031417, 8.083723190069185e-09)
#
# residual sugar chlorides
# (0.05560953520353217, 0.026170790715020646)
# residual sugar free sulfur dioxide
# (0.1870489951042869, 4.6847352594896096e-14)
# residual sugar total sulfur dioxide
# (0.20302788169710123, 2.449285445133578e-16)
# residual sugar density
# (0.35528337098337653, 9.013041728300921e-49)
# residual sugar pH
# (-0.08565242221887162, 0.0006065914586969014)
# residual sugar sulphates
# (0.005527121339138299, 0.8252134336677415)
# residual sugar alcohol
# (0.04207543720973106, 0.09258424937202335)
# residual sugar quality
# (0.01373163734006628, 0.5832180131585295)
# chlorides fixed acidity
# (0.09370518632130542, 0.00017517459785438793)
# chlorides volatile acidity
# (0.061297772476461544, 0.014224905521195211)
# chlorides citric acid
# (0.20382291382904166, 1.8637050331359642e-16)
# chlorides residual sugar
# (0.05560953520353217, 0.026170790715020646)
#
# chlorides free sulfur dioxide
# (0.005562147004781115, 0.8241238441628107)
# chlorides total sulfur dioxide
# (0.0474004682590752, 0.05809120223360299)
# chlorides density
# (0.20063232664151334, 5.541457564531321e-16)
# chlorides pH
# (-0.26502613117322743, 4.149216937884377e-27)
# chlorides sulphates
# (0.3712604812854257, 1.986309610891376e-53)
# chlorides alcohol
# (-0.22114054478828266, 3.654950031876242e-19)
# chlorides quality
# (-0.1289065599300527, 2.3133826540602144e-07)
# free sulfur dioxide fixed acidity
# (-0.15379419286482512, 6.335579450533808e-10)
# free sulfur dioxide volatile acidity
# (-0.010503827006591825, 0.6747010640337184)
# free sulfur dioxide citric acid
# (-0.06097812919230491, 0.014739157341032214)
# free sulfur dioxide residual sugar
# (0.1870489951042869, 4.6847352594896096e-14)
# free sulfur dioxide chlorides
# (0.005562147004781115, 0.8241238441628107)
#
# free sulfur dioxide total sulfur dioxide
# (0.6676664504810215, 6.404722954687316e-207)
# free sulfur dioxide density
# (-0.02194583116349004, 0.38049846539572213)
# free sulfur dioxide pH
# (0.07037749850494185, 0.004869975386135814)
# free sulfur dioxide sulphates
# (0.05165757184282854, 0.038883210655314054)
# free sulfur dioxide alcohol
# (-0.06940835356499987, 0.005492313852321059)
# free sulfur dioxide quality
# (-0.05065605724427638, 0.042833979508175565)
# total sulfur dioxide fixed acidity
# (-0.11318144304548113, 5.709032856583959e-06)
# total sulfur dioxide volatile acidity
# (0.07647000482092817, 0.002213856792193685)
# total sulfur dioxide citric acid
# (0.035533023931161464, 0.15554537485346961)
# total sulfur dioxide residual sugar
# (0.20302788169710123, 2.449285445133578e-16)
# total sulfur dioxide chlorides
# (0.0474004682590752, 0.05809120223360299)
# total sulfur dioxide free sulfur dioxide
# (0.6676664504810215, 6.404722954687316e-207)
#
# total sulfur dioxide density
# (0.07126947620310296, 0.004354283989415269)
# total sulfur dioxide pH
# (-0.06649455901285588, 0.007818340576409224)
# total sulfur dioxide sulphates
# (0.04294683623953828, 0.08601834757029696)
# total sulfur dioxide alcohol
# (-0.20565394374367094, 9.890520390087737e-17)
# total sulfur dioxide quality
# (-0.18510028892653785, 8.62170342366267e-14)
# density fixed acidity
# (0.6680472921189743, 3.0747470608589978e-207)
# density volatile acidity
# (0.02202623219521651, 0.3787553541321885)
# density citric acid
# (0.36494717521125175, 1.4787950814489143e-51)
# density residual sugar
# (0.35528337098337653, 9.013041728300921e-49)
# density chlorides
# (0.20063232664151334, 5.541457564531321e-16)
# density free sulfur dioxide
# (-0.02194583116349004, 0.38049846539572213)
# density total sulfur dioxide
# (0.07126947620310296, 0.004354283989415269)
#
# density pH
# (-0.34169933478503145, 5.117102011974621e-45)
# density sulphates
# (0.14850641172078502, 2.4184741727651457e-09)
# density alcohol
# (-0.4961797702417011, 3.938835339993499e-100)
# density quality
# (-0.1749192277833501, 1.8749566520107985e-12)
# pH fixed acidity
# (-0.6829781945685314, 4.063034039847446e-220)
# pH volatile acidity
# (0.2349372944073932, 1.7189939570072257e-21)
# pH citric acid
# (-0.5419041447395095, 1.0072013259121818e-122)
# pH residual sugar
# (-0.08565242221887162, 0.0006065914586969014)
# pH chlorides
# (-0.26502613117322743, 4.149216937884377e-27)
# pH free sulfur dioxide
# (0.07037749850494185, 0.004869975386135814)
# pH total sulfur dioxide
# (-0.06649455901285588, 0.007818340576409224)
# pH density
# (-0.34169933478503145, 5.117102011974621e-45)
#
# pH sulphates
# (-0.1966476023043702, 2.106734103689356e-15)
# pH alcohol
# (0.20563250850549822, 9.96449774146556e-17)
# pH quality
# (-0.05773139120538214, 0.020962778651490887)
# sulphates fixed acidity
# (0.18300566393215348, 1.6486524776131155e-13)
# sulphates volatile acidity
# (-0.26098668528328955, 2.6069256588975935e-26)
# sulphates citric acid
# (0.3127700438544169, 1.2652623915699414e-37)
# sulphates residual sugar
# (0.005527121339138299, 0.8252134336677415)
# sulphates chlorides
# (0.3712604812854257, 1.986309610891376e-53)
# sulphates free sulfur dioxide
# (0.05165757184282854, 0.038883210655314054)
# sulphates total sulfur dioxide
# (0.04294683623953828, 0.08601834757029696)
# sulphates density
# (0.14850641172078502, 2.4184741727651457e-09)
# sulphates pH
# (-0.1966476023043702, 2.106734103689356e-15)
#
# sulphates alcohol
# (0.09359475041046736, 0.00017830530851016817)
# sulphates quality
# (0.25139707906926123, 1.8020884534539657e-24)
# alcohol fixed acidity
# (-0.061668270628151084, 0.013648681625104516)
# alcohol volatile acidity
# (-0.20228802715325606, 3.1551902158325624e-16)
# alcohol citric acid
# (0.10990324664156681, 1.0594619210193064e-05)
# alcohol residual sugar
# (0.04207543720973106, 0.09258424937202335)
# alcohol chlorides
# (-0.22114054478828266, 3.654950031876242e-19)
# alcohol free sulfur dioxide
# (-0.06940835356499987, 0.005492313852321059)
# alcohol total sulfur dioxide
# (-0.20565394374367094, 9.890520390087737e-17)
# alcohol density
# (-0.4961797702417011, 3.938835339993499e-100)
# alcohol pH
# (0.20563250850549822, 9.96449774146556e-17)
# alcohol sulphates
# (0.09359475041046736, 0.00017830530851016817)
#
# alcohol quality
# (0.4761663240011362, 2.831476974777616e-91)
# quality fixed acidity
# (0.12405164911322429, 6.495635009282964e-07)
# quality volatile acidity
# (-0.3905577802640073, 2.0517148070151443e-59)
# quality citric acid
# (0.22637251431804137, 4.9912952505121016e-20)
# quality residual sugar
# (0.01373163734006628, 0.5832180131585295)
# quality chlorides
# (-0.1289065599300527, 2.3133826540602144e-07)
# quality free sulfur dioxide
# (-0.05065605724427638, 0.042833979508175565)
# quality total sulfur dioxide
# (-0.18510028892653785, 8.62170342366267e-14)
# quality density
# (-0.1749192277833501, 1.8749566520107985e-12)
# quality pH
# (-0.05773139120538214, 0.020962778651490887)
# quality sulphates
# (0.25139707906926123, 1.8020884534539657e-24)
# quality alcohol
# (0.4761663240011362, 2.831476974777616e-91)

# %% [markdown]
# the **pearson rank** between these quantities are : -
#
# - fixed acidity  and citric acid ( 0.6717034347641061 )
# - fixed acidity and density ( 0.6680472921189743 )
# - free sulfur dioxide and total sulfur dioxide ( 0.6676664504810215 )
# - alcohol and quality ( 0.47616632400113607 )
# - fixed acidity and pH ( - 0.6829781945685314 )
# - volatile acidity and citric acid ( - 0.55249568455958 )
# - pH and  citric acid ( - 0.5419041447395097 )
# - alcohol and density ( - 0.49617977024170107 )
#
# ###Pearson Rank###
#
# Rank varies between - 1 to + 1.
#
#    *  +1 = strong positive relation between two variables
#    *  -1 = strong negative relation between two variables
#    * 0 =  no relation
#
# positive relation
# - fixed acidity  and citric acid ( x=0.6717034347641061 )
# - fixed acidity and density ( 0.6680472921189743 )
# - free sulfur dioxide and total sulfur dioxide ( 0.6676664504810215 )
# - alcohol and quality ( 0.47616632400113607 )
#
# negative relation
# - fixed acidity and pH ( - 0.6829781945685314 )
# - volatile acidity and citric acid ( - 0.55249568455958 )
# - pH and  citric acid ( - 0.5419041447395097 )
# - alcohol and density ( - 0.49617977024170107 )

# %%
x=df['fixed acidity']
y=df["citric acid"]
plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()

x=df['fixed acidity']
y=df["density"]

plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()

x=df['fixed acidity']
y=df["pH"]

plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()

# %%
x=df['alcohol']
y=df["density"]
plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()


x=df['alcohol']
y=df["quality"]
plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()


x=df['pH']
y=df["citric acid"]
plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()


x=df['volatile acidity']
y=df["citric acid"]
plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()
    

x=df['free sulfur dioxide']
y=df["total sulfur dioxide"]
plt.axvline(x.mean(),c='r',label='mean-x')
plt.axhline(y.mean(),c='k',label='mean-y')
plt.scatter(x,y,label='x-y plot')
plt.legend()
plt.show()

# %%
k=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']
from scipy.stats import pearsonr


def function(x,y):
  z = pearsonr(x,y)
  return z


L=[]

for i in k:
  for j in k:
    if i!=j:
      x=df[i] 
      y=df[j]
      M=function(x,y)
      Z=(i,j)
      L.append(Z)
      L.append(M)
      print(i,j)
      print(function(x,y))
    else:
      print("next")
# Out:
# next
# fixed acidity volatile acidity
# (-0.2561308947703821, 2.2767204431779706e-25)
# fixed acidity citric acid
# (0.671703434764106, 2.5353210618214457e-210)
# fixed acidity residual sugar
# (0.11477672449492143, 4.199464867686219e-06)
# fixed acidity chlorides
# (0.09370518632130542, 0.00017517459785438793)
# fixed acidity free sulfur dioxide
# (-0.15379419286482512, 6.335579450533808e-10)
# fixed acidity total sulfur dioxide
# (-0.11318144304548113, 5.709032856583959e-06)
# fixed acidity density
# (0.6680472921189743, 3.0747470608589978e-207)
# fixed acidity pH
# (-0.6829781945685314, 4.063034039847446e-220)
# fixed acidity sulphates
# (0.18300566393215348, 1.6486524776131155e-13)
# fixed acidity alcohol
# (-0.061668270628151084, 0.013648681625104516)
# fixed acidity quality
# (0.12405164911322429, 6.495635009282964e-07)
# volatile acidity fixed acidity
# (-0.2561308947703821, 2.2767204431779706e-25)
# next
# volatile acidity citric acid
# (-0.55249568455958, 1.8056634143422275e-128)
# volatile acidity residual sugar
# (0.0019178819627907306, 0.9389167807222325)
# volatile acidity chlorides
# (0.061297772476461544, 0.014224905521195211)
# volatile acidity free sulfur dioxide
# (-0.010503827006591825, 0.6747010640337184)
# volatile acidity total sulfur dioxide
# (0.07647000482092817, 0.002213856792193685)
# volatile acidity density
# (0.02202623219521651, 0.3787553541321885)
# volatile acidity pH
# (0.2349372944073932, 1.7189939570072257e-21)
# volatile acidity sulphates
# (-0.26098668528328955, 2.6069256588975935e-26)
# volatile acidity alcohol
# (-0.20228802715325606, 3.1551902158325624e-16)
# volatile acidity quality
# (-0.3905577802640073, 2.0517148070151443e-59)
# citric acid fixed acidity
# (0.671703434764106, 2.5353210618214457e-210)
# citric acid volatile acidity
# (-0.55249568455958, 1.8056634143422275e-128)
# next
# citric acid residual sugar
# (0.14357716157031417, 8.083723190069185e-09)
# citric acid chlorides
# (0.20382291382904166, 1.8637050331359642e-16)
# citric acid free sulfur dioxide
# (-0.06097812919230491, 0.014739157341032214)
# citric acid total sulfur dioxide
# (0.035533023931161464, 0.15554537485346961)
# citric acid density
# (0.36494717521125175, 1.4787950814489143e-51)
# citric acid pH
# (-0.5419041447395095, 1.0072013259121818e-122)
# citric acid sulphates
# (0.3127700438544169, 1.2652623915699414e-37)
# citric acid alcohol
# (0.10990324664156681, 1.0594619210193064e-05)
# citric acid quality
# (0.22637251431804137, 4.9912952505121016e-20)
# residual sugar fixed acidity
# (0.11477672449492143, 4.199464867686219e-06)
# residual sugar volatile acidity
# (0.0019178819627907306, 0.9389167807222325)
# residual sugar citric acid
# (0.14357716157031417, 8.083723190069185e-09)
# next
# residual sugar chlorides
# (0.05560953520353217, 0.026170790715020646)
# residual sugar free sulfur dioxide
# (0.1870489951042869, 4.6847352594896096e-14)
# residual sugar total sulfur dioxide
# (0.20302788169710123, 2.449285445133578e-16)
# residual sugar density
# (0.35528337098337653, 9.013041728300921e-49)
# residual sugar pH
# (-0.08565242221887162, 0.0006065914586969014)
# residual sugar sulphates
# (0.005527121339138299, 0.8252134336677415)
# residual sugar alcohol
# (0.04207543720973106, 0.09258424937202335)
# residual sugar quality
# (0.01373163734006628, 0.5832180131585295)
# chlorides fixed acidity
# (0.09370518632130542, 0.00017517459785438793)
# chlorides volatile acidity
# (0.061297772476461544, 0.014224905521195211)
# chlorides citric acid
# (0.20382291382904166, 1.8637050331359642e-16)
# chlorides residual sugar
# (0.05560953520353217, 0.026170790715020646)
# next
# chlorides free sulfur dioxide
# (0.005562147004781115, 0.8241238441628107)
# chlorides total sulfur dioxide
# (0.0474004682590752, 0.05809120223360299)
# chlorides density
# (0.20063232664151334, 5.541457564531321e-16)
# chlorides pH
# (-0.26502613117322743, 4.149216937884377e-27)
# chlorides sulphates
# (0.3712604812854257, 1.986309610891376e-53)
# chlorides alcohol
# (-0.22114054478828266, 3.654950031876242e-19)
# chlorides quality
# (-0.1289065599300527, 2.3133826540602144e-07)
# free sulfur dioxide fixed acidity
# (-0.15379419286482512, 6.335579450533808e-10)
# free sulfur dioxide volatile acidity
# (-0.010503827006591825, 0.6747010640337184)
# free sulfur dioxide citric acid
# (-0.06097812919230491, 0.014739157341032214)
# free sulfur dioxide residual sugar
# (0.1870489951042869, 4.6847352594896096e-14)
# free sulfur dioxide chlorides
# (0.005562147004781115, 0.8241238441628107)
# next
# free sulfur dioxide total sulfur dioxide
# (0.6676664504810215, 6.404722954687316e-207)
# free sulfur dioxide density
# (-0.02194583116349004, 0.38049846539572213)
# free sulfur dioxide pH
# (0.07037749850494185, 0.004869975386135814)
# free sulfur dioxide sulphates
# (0.05165757184282854, 0.038883210655314054)
# free sulfur dioxide alcohol
# (-0.06940835356499987, 0.005492313852321059)
# free sulfur dioxide quality
# (-0.05065605724427638, 0.042833979508175565)
# total sulfur dioxide fixed acidity
# (-0.11318144304548113, 5.709032856583959e-06)
# total sulfur dioxide volatile acidity
# (0.07647000482092817, 0.002213856792193685)
# total sulfur dioxide citric acid
# (0.035533023931161464, 0.15554537485346961)
# total sulfur dioxide residual sugar
# (0.20302788169710123, 2.449285445133578e-16)
# total sulfur dioxide chlorides
# (0.0474004682590752, 0.05809120223360299)
# total sulfur dioxide free sulfur dioxide
# (0.6676664504810215, 6.404722954687316e-207)
# next
# total sulfur dioxide density
# (0.07126947620310296, 0.004354283989415269)
# total sulfur dioxide pH
# (-0.06649455901285588, 0.007818340576409224)
# total sulfur dioxide sulphates
# (0.04294683623953828, 0.08601834757029696)
# total sulfur dioxide alcohol
# (-0.20565394374367094, 9.890520390087737e-17)
# total sulfur dioxide quality
# (-0.18510028892653785, 8.62170342366267e-14)
# density fixed acidity
# (0.6680472921189743, 3.0747470608589978e-207)
# density volatile acidity
# (0.02202623219521651, 0.3787553541321885)
# density citric acid
# (0.36494717521125175, 1.4787950814489143e-51)
# density residual sugar
# (0.35528337098337653, 9.013041728300921e-49)
# density chlorides
# (0.20063232664151334, 5.541457564531321e-16)
# density free sulfur dioxide
# (-0.02194583116349004, 0.38049846539572213)
# density total sulfur dioxide
# (0.07126947620310296, 0.004354283989415269)
# next
# density pH
# (-0.34169933478503145, 5.117102011974621e-45)
# density sulphates
# (0.14850641172078502, 2.4184741727651457e-09)
# density alcohol
# (-0.4961797702417011, 3.938835339993499e-100)
# density quality
# (-0.1749192277833501, 1.8749566520107985e-12)
# pH fixed acidity
# (-0.6829781945685314, 4.063034039847446e-220)
# pH volatile acidity
# (0.2349372944073932, 1.7189939570072257e-21)
# pH citric acid
# (-0.5419041447395095, 1.0072013259121818e-122)
# pH residual sugar
# (-0.08565242221887162, 0.0006065914586969014)
# pH chlorides
# (-0.26502613117322743, 4.149216937884377e-27)
# pH free sulfur dioxide
# (0.07037749850494185, 0.004869975386135814)
# pH total sulfur dioxide
# (-0.06649455901285588, 0.007818340576409224)
# pH density
# (-0.34169933478503145, 5.117102011974621e-45)
# next
# pH sulphates
# (-0.1966476023043702, 2.106734103689356e-15)
# pH alcohol
# (0.20563250850549822, 9.96449774146556e-17)
# pH quality
# (-0.05773139120538214, 0.020962778651490887)
# sulphates fixed acidity
# (0.18300566393215348, 1.6486524776131155e-13)
# sulphates volatile acidity
# (-0.26098668528328955, 2.6069256588975935e-26)
# sulphates citric acid
# (0.3127700438544169, 1.2652623915699414e-37)
# sulphates residual sugar
# (0.005527121339138299, 0.8252134336677415)
# sulphates chlorides
# (0.3712604812854257, 1.986309610891376e-53)
# sulphates free sulfur dioxide
# (0.05165757184282854, 0.038883210655314054)
# sulphates total sulfur dioxide
# (0.04294683623953828, 0.08601834757029696)
# sulphates density
# (0.14850641172078502, 2.4184741727651457e-09)
# sulphates pH
# (-0.1966476023043702, 2.106734103689356e-15)
# next
# sulphates alcohol
# (0.09359475041046736, 0.00017830530851016817)
# sulphates quality
# (0.25139707906926123, 1.8020884534539657e-24)
# alcohol fixed acidity
# (-0.061668270628151084, 0.013648681625104516)
# alcohol volatile acidity
# (-0.20228802715325606, 3.1551902158325624e-16)
# alcohol citric acid
# (0.10990324664156681, 1.0594619210193064e-05)
# alcohol residual sugar
# (0.04207543720973106, 0.09258424937202335)
# alcohol chlorides
# (-0.22114054478828266, 3.654950031876242e-19)
# alcohol free sulfur dioxide
# (-0.06940835356499987, 0.005492313852321059)
# alcohol total sulfur dioxide
# (-0.20565394374367094, 9.890520390087737e-17)
# alcohol density
# (-0.4961797702417011, 3.938835339993499e-100)
# alcohol pH
# (0.20563250850549822, 9.96449774146556e-17)
# alcohol sulphates
# (0.09359475041046736, 0.00017830530851016817)
# next
# alcohol quality
# (0.4761663240011362, 2.831476974777616e-91)
# quality fixed acidity
# (0.12405164911322429, 6.495635009282964e-07)
# quality volatile acidity
# (-0.3905577802640073, 2.0517148070151443e-59)
# quality citric acid
# (0.22637251431804137, 4.9912952505121016e-20)
# quality residual sugar
# (0.01373163734006628, 0.5832180131585295)
# quality chlorides
# (-0.1289065599300527, 2.3133826540602144e-07)
# quality free sulfur dioxide
# (-0.05065605724427638, 0.042833979508175565)
# quality total sulfur dioxide
# (-0.18510028892653785, 8.62170342366267e-14)
# quality density
# (-0.1749192277833501, 1.8749566520107985e-12)
# quality pH
# (-0.05773139120538214, 0.020962778651490887)
# quality sulphates
# (0.25139707906926123, 1.8020884534539657e-24)
# quality alcohol
# (0.4761663240011362, 2.831476974777616e-91)
# next

# %%
len(L)
# Out:
# 264

# %%
keys_name=[]
keys_values=[]
for i in range(263):
  if i==0:
    keys_name.append(L[i])
  elif i%2==0:
    keys_name.append(L[i])
  else:
    keys_values.append(L[i])



keys_name
keys_values

# %%
df = pd.DataFrame(list(zip(keys_name, keys_values)),
               columns =['Name', 'values'])

df["values"][:12]
# Out:
# 0     (-0.2561308947703821, 2.2767204431779706e-25)
# 1      (0.671703434764106, 2.5353210618214457e-210)
# 2      (0.11477672449492143, 4.199464867686219e-06)
# 3     (0.09370518632130542, 0.00017517459785438793)
# 4     (-0.15379419286482512, 6.335579450533808e-10)
# 5     (-0.11318144304548113, 5.709032856583959e-06)
# 6     (0.6680472921189743, 3.0747470608589978e-207)
# 7     (-0.6829781945685314, 4.063034039847446e-220)
# 8     (0.18300566393215348, 1.6486524776131155e-13)
# 9     (-0.061668270628151084, 0.013648681625104516)
# 10     (0.12405164911322429, 6.495635009282964e-07)
# 11    (-0.2561308947703821, 2.2767204431779706e-25)
# Name: values, dtype: object
